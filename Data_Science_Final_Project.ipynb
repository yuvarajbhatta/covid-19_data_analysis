# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/yuva3995/Desktop/DataScience/tested_worldwide.csv")
data
# Out:
#              Date Country_Region     Province_State  positive  active  \
# 0      2020-01-16        Iceland         All States       3.0     NaN
# 1      2020-01-17        Iceland         All States       4.0     NaN
# 2      2020-01-18        Iceland         All States       7.0     NaN
# 3      2020-01-20    South Korea         All States       1.0     NaN
# 4      2020-01-22  United States         All States       0.0     NaN
# ...           ...            ...                ...       ...     ...
# 27636  2020-11-09      Australia         Queensland       NaN     8.0
# 27637  2020-11-09      Australia    South Australia       NaN    19.0
# 27638  2020-11-09      Australia           Tasmania       NaN     0.0
# 27639  2020-11-09      Australia           Victoria       NaN     4.0
# 27640  2020-11-09      Australia  Western Australia       NaN    10.0
#
#        hospitalized  hospitalizedCurr  recovered  death  total_tested  \
# ...

# %%
data.describe()
# Out:
#            positive         active  hospitalized  hospitalizedCurr  \
# count  2.339900e+04   17808.000000   8410.000000      14561.000000
# mean   8.904194e+04   19029.893138   7495.328062        956.721585
# std    4.881561e+05   45841.435758  14774.294866       2612.451452
# min    0.000000e+00     -10.000000      0.000000          0.000000
# 25%    6.350000e+02     118.000000    553.000000         37.000000
# 50%    8.044000e+03    2332.500000   2591.500000        280.000000
# 75%    5.281150e+04   15101.750000   8199.000000        808.000000
# max    9.761481e+06  558636.000000  89995.000000      39055.000000
#
#            recovered          death  total_tested  daily_tested  \
# count   18015.000000   23631.000000  2.672900e+04  2.646700e+04
# mean    25774.837746    3073.709196  1.485408e+06  1.908511e+04
# std     61599.922450   14757.380517  7.471080e+06  9.274723e+04
# min         0.000000       0.000000  0.000000e+00 -1.243606e+06
# ...

# %%
data.describe()
# Out:
#            positive         active  hospitalized  hospitalizedCurr  \
# count  2.339900e+04   17808.000000   8410.000000      14561.000000
# mean   8.904194e+04   19029.893138   7495.328062        956.721585
# std    4.881561e+05   45841.435758  14774.294866       2612.451452
# min    0.000000e+00     -10.000000      0.000000          0.000000
# 25%    6.350000e+02     118.000000    553.000000         37.000000
# 50%    8.044000e+03    2332.500000   2591.500000        280.000000
# 75%    5.281150e+04   15101.750000   8199.000000        808.000000
# max    9.761481e+06  558636.000000  89995.000000      39055.000000
#
#            recovered          death  total_tested  daily_tested  \
# count   18015.000000   23631.000000  2.672900e+04  2.646700e+04
# mean    25774.837746    3073.709196  1.485408e+06  1.908511e+04
# std     61599.922450   14757.380517  7.471080e+06  9.274723e+04
# min         0.000000       0.000000  0.000000e+00 -1.243606e+06
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Country_Region', 'Province_State', 'positive', 'active',
#        'hospitalized', 'hospitalizedCurr', 'recovered', 'death',
#        'total_tested', 'daily_tested', 'daily_positive'],
#       dtype='object')

# %%
sns.relplot(x="positive", y = "hospitalized", data = data,)

# %%
sns.relplot(x="positive", y = "active", data = data,)

# %%
sns.relplot(x="hospitalized", y = "death", data = data,)

# %%
sns.relplot(x="hospitalizedCurr", y = "recovered", data = data,)

# %%
sns.relplot(x="daily_tested", y = "daily_positive", data = data,)

# %%
sns.pairplot(data)
